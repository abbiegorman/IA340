# %% [markdown]
# # Mini Project

# %% [markdown]
# ## By: Jahnavi & Abbie

# %% [markdown]
# ## Our data depicts the amount of natural resources produced in each state per year.

# %% [markdown]
# ### We intend to look at the growth in production rate of natural resources per state over a 2 year period (2022-2023).

# %% [markdown]
# ### Lab 5 Portion

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia340-2024-fall-01-5u7438/fiscal_year_production.csv') # load the data from s3
df.head() #show the top 5 rows
# Out:
#    Fiscal Year Land Class Land Category       State    County  FIPS Code  \
# 0         2003    Federal       Onshore  New Mexico      Eddy    35015.0
# 1         2003    Federal       Onshore    Colorado  Huerfano     8055.0
# 2         2003    Federal       Onshore     Wyoming   Natrona    56025.0
# 3         2003    Federal       Onshore     Wyoming   Natrona    56025.0
# 4         2003    Federal       Onshore    Colorado  Gunnison     8051.0
#
#   Offshore Region     Product    Volume
# 0             NaN  Salt (ton)    260806
# 1             NaN   Gas (mcf)  14390664
# 2             NaN   Oil (bbl)   2987859
# 3             NaN   Gas (mcf)  34833693
# 4             NaN  Coal (ton)   8151045

# %%
df.shape
# Out:
# (15181, 9)

# %%
df['Product']
# Out:
# 0        Salt (ton)
# 1         Gas (mcf)
# 2         Oil (bbl)
# 3         Gas (mcf)
# 4        Coal (ton)
#             ...
# 15176     Gas (mcf)
# 15177     Gas (mcf)
# 15178    Coal (ton)
# 15179     Gas (mcf)
# 15180     Oil (bbl)
# Name: Product, Length: 15181, dtype: object

# %%
df.sort_values(by='Fiscal Year')
# Out:
#        Fiscal Year         Land Class Land Category       State       County  \
# 0             2003            Federal       Onshore  New Mexico         Eddy
# 455           2003  Mixed Exploratory       Onshore     Montana       Wibaux
# 456           2003            Federal       Onshore  California     Imperial
# 457           2003            Federal       Onshore  California     Imperial
# 458           2003            Federal       Onshore   Louisiana    Bienville
# ...            ...                ...           ...         ...          ...
# 14741         2023            Federal       Onshore   Louisiana      Lincoln
# 14742         2023            Federal       Onshore     Montana    Roosevelt
# 14743         2023            Federal       Onshore  California  San Joaquin
# 14745         2023            Federal       Onshore        Ohio        Perry
# 15180         2023            Federal       Onshore    Colorado     Gunnison
#
#        FIPS Code Offshore Region  \
# ...

# %%
df[0:5]
# Out:
#    Fiscal Year Land Class Land Category       State    County  FIPS Code  \
# 0         2003    Federal       Onshore  New Mexico      Eddy    35015.0
# 1         2003    Federal       Onshore    Colorado  Huerfano     8055.0
# 2         2003    Federal       Onshore     Wyoming   Natrona    56025.0
# 3         2003    Federal       Onshore     Wyoming   Natrona    56025.0
# 4         2003    Federal       Onshore    Colorado  Gunnison     8051.0
#
#   Offshore Region     Product    Volume
# 0             NaN  Salt (ton)    260806
# 1             NaN   Gas (mcf)  14390664
# 2             NaN   Oil (bbl)   2987859
# 3             NaN   Gas (mcf)  34833693
# 4             NaN  Coal (ton)   8151045

# %%
df[df['Fiscal Year']>2022]
# Out:
#        Fiscal Year Land Class Land Category         State      County  \
# 14520         2023    Federal       Onshore  North Dakota    Williams
# 14521         2023    Federal       Onshore      Colorado        Weld
# 14522         2023    Federal       Onshore      Colorado        Weld
# 14523         2023    Federal       Onshore          Utah  Washington
# 14524         2023    Federal       Onshore  North Dakota    Mckenzie
# ...            ...        ...           ...           ...         ...
# 15176         2023    Federal       Onshore      Colorado    Huerfano
# 15177         2023    Federal       Onshore  North Dakota    Mckenzie
# 15178         2023    Federal       Onshore      Colorado    Gunnison
# 15179         2023    Federal       Onshore      Colorado    Gunnison
# 15180         2023    Federal       Onshore      Colorado    Gunnison
#
#        FIPS Code Offshore Region           Product    Volume
# 14520    38105.0             NaN  Leonardite (ton)     15121
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15181 entries, 0 to 15180
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fiscal Year      15181 non-null  int64
#  1   Land Class       15181 non-null  object
#  2   Land Category    15181 non-null  object
#  3   State            14831 non-null  object
#  4   County           14831 non-null  object
#  5   FIPS Code        14831 non-null  float64
#  6   Offshore Region  140 non-null    object
#  7   Product          15181 non-null  object
#  8   Volume           15181 non-null  int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.0+ MB

# %%
df = df.drop('Offshore Region', axis=1)

# %%
df = df.rename(columns={"Fiscal Year": "Year", "Product": "Resource", "Land Class":"Class" }) 
df.head()
# Out:
#    Year    Class Land Category       State    County  FIPS Code    Resource  \
# 0  2003  Federal       Onshore  New Mexico      Eddy    35015.0  Salt (ton)
# 1  2003  Federal       Onshore    Colorado  Huerfano     8055.0   Gas (mcf)
# 2  2003  Federal       Onshore     Wyoming   Natrona    56025.0   Oil (bbl)
# 3  2003  Federal       Onshore     Wyoming   Natrona    56025.0   Gas (mcf)
# 4  2003  Federal       Onshore    Colorado  Gunnison     8051.0  Coal (ton)
#
#      Volume
# 0    260806
# 1  14390664
# 2   2987859
# 3  34833693
# 4   8151045

# %%
df.isnull().sum()
# Out:
# Year             0
# Class            0
# Land Category    0
# State            0
# County           0
# FIPS Code        0
# Resource         0
# Volume           0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Year             0
# Class            0
# Land Category    0
# State            0
# County           0
# FIPS Code        0
# Resource         0
# Volume           0
# dtype: int64

# %%
df.describe()
# Out:
#                Year     FIPS Code        Volume
# count  14831.000000  14831.000000  1.483100e+04
# mean    2012.906008  31340.597060  1.303678e+07
# std        5.953829  16400.690156  1.076018e+08
# min     2003.000000   1003.000000  1.000000e+00
# 25%     2008.000000  20195.000000  2.807000e+03
# 50%     2013.000000  32003.000000  3.017400e+04
# 75%     2018.000000  48071.000000  4.141775e+05
# max     2023.000000  56045.000000  2.849230e+09

# %%
df = df[(df['Year']>=2022) & (df['Volume']>=10000)] #filter data
df.describe()
# Out:
#               Year     FIPS Code        Volume
# count   816.000000    816.000000  8.160000e+02
# mean   2022.493873  32548.715686  2.627472e+07
# std       0.500269  17254.075237  1.384505e+08
# min    2022.000000   1003.000000  1.004000e+04
# 25%    2022.000000  20093.000000  4.405850e+04
# 50%    2022.000000  35039.000000  2.176050e+05
# 75%    2023.000000  48407.000000  2.068622e+06
# max    2023.000000  56045.000000  2.009766e+09

# %%
df['State'].value_counts()
# Out:
# State
# Wyoming          114
# Colorado          90
# Oklahoma          73
# Utah              64
# Montana           64
# New Mexico        63
# North Dakota      56
# California        51
# Texas             45
# Kansas            26
# Arkansas          26
# Louisiana         25
# Nevada            22
# Mississippi       18
# Ohio              12
# Alaska            10
# Alabama           10
# Michigan           9
# South Dakota       8
# West Virginia      8
# Kentucky           6
# Missouri           6
# Virginia           4
# Pennsylvania       2
# Idaho              2
# Nebraska           2
# Name: count, dtype: int64

# %%
df = df[['State','Class','Year','Volume']] # keep specific columns 
df.head()
# Out:
#               State              Class  Year   Volume
# 13846    California            Federal  2022  2549078
# 13848      Colorado  Mixed Exploratory  2022   125052
# 13850   Mississippi            Federal  2022    17317
# 13852  North Dakota            Federal  2022  7193534
# 13854       Wyoming            Federal  2022  1739945

# %%
df.set_index('Year',inplace=True) #define the index
df.head()
# Out:
#              State              Class   Volume
# Year
# 2022    California            Federal  2549078
# 2022      Colorado  Mixed Exploratory   125052
# 2022   Mississippi            Federal    17317
# 2022  North Dakota            Federal  7193534
# 2022       Wyoming            Federal  1739945

# %% [markdown]
# # Lab 6 Portion

# %%
pip install jupyter-ai~=1.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-ai[all]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
from botocore.exceptions import ClientError
import json

def get_secret(secret_name):
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        raise e

    secret = get_secret_value_response['SecretString']
    
    return json.loads(secret)

# %%
import psycopg2

conn = psycopg2.connect(host=get_secret('postgresql')['host'],
                      user='IA340',
                      password = get_secret('postgresql')['password'],
                      dbname=get_secret('postgresql')['engine'])

cur = conn.cursor()

# %%
import os
os.environ["OPENAI_API_KEY"] = get_secret('openai')['api_key']

# %%
# %load_ext jupyter_ai_magics
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# bedrock
# * bedrock:amazon.titan-text-express-v1
# * bedrock:amazon.titan-text-lite-v1
# * bedrock:amazon.titan-text-premier-v1:0
# * bedrock:ai21.j2-ultra-v1
# * bedrock:ai21.j2-mid-v1
# * bedrock:ai21.jamba-instruct-v1:0
# * bedrock:cohere.command-light-text-v14
# * bedrock:cohere.command-text-v14
# * bedrock:cohere.command-r-v1:0
# * bedrock:cohere.command-r-plus-v1:0
# * bedrock:meta.llama2-13b-chat-v1
# * bedrock:meta.llama2-70b-chat-v1
# * bedrock:meta.llama3-8b-instruct-v1:0
# * bedrock:meta.llama3-70b-instruct-v1:0
# * bedrock:meta.llama3-1-8b-instruct-v1:0
# * bedrock:meta.llama3-1-70b-instruct-v1:0
# * bedrock:meta.llama3-1-405b-instruct-v1:0
# * bedrock:mistral.mistral-7b-instruct-v0:2
# ...

# %%
# %%ai gpt4
# what is in the {df} in {In[75]}
# Out:
# The displayed DataFrame, after setting 'Year' as the index, has the following information:
#
# - 'Year' is the index with years 2022 and 2023.
# - 'State' is a column indicating the name of the state. The states listed include California, Colorado, Mississippi, North Dakota, and Wyoming.
# - 'Class' is a column indicating the class of the state. It lists 'Federal' for most states and 'Mixed Exploratory' for Colorado in 2022.
# - 'Volume' is a column indicating some numerical volume related to each state for each year. The volume ranges from as low as 17317 to as high as 88815693.
# - The DataFrame has 816 rows in total.
#
# This data is the first 5 rows and some random rows of the DataFrame after setting 'Year' as the index.

# %%
# %%ai gpt4 -f code
#
# calculate the year-over-year volume growth rate for each state of each year in dataframe {df} in {In[75]} use a line chart to show the result
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is your DataFrame
df['YoY Growth'] = df.groupby('State')['Volume'].pct_change()

# Reset index for pivot
df.reset_index(inplace=True)

# Pivot DataFrame to have years as columns for each state
df_pivot = df.pivot_table(index='State', columns='Year', values='YoY Growth')

# Plotting the data
plt.figure(figsize=(10,6))
for state in df_pivot.index:
    plt.plot(df_pivot.columns, df_pivot.loc[state], marker='o', label=state)
plt.xlabel('Year')
plt.ylabel('YoY Growth Rate')
plt.title('Year-over-Year Volume Growth Rate by State')
plt.legend()
plt.grid(True)
plt.show()

#This code calculates the year-over-year growth rate for 'Volume' in each state, pivots the DataFrame to prepare it for plotting, and then creates a line chart to visualize the growth rate for each state over the years.

# %% [markdown]
# ### Montana, Arkansas, and Utah had the highest growth rate in natural resource production out of the 50 states.
